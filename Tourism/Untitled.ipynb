# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('UNWTO_tourism_data.csv')

# Melt the DataFrame to reshape it
melted_df = pd.melt(df, id_vars=['Country', 'Report Type', 'Category', 'Subcategory', 'Metric'], var_name='Year', value_name='Value')

# %%
df
# Out:
#           Country                     Report Type  \
# 0     AFGHANISTAN  Domestic Tourism-Accommodation
# 1     AFGHANISTAN  Domestic Tourism-Accommodation
# 2     AFGHANISTAN  Domestic Tourism-Accommodation
# 3     AFGHANISTAN  Domestic Tourism-Accommodation
# 4     AFGHANISTAN          Domestic Tourism-Trips
# ...           ...                             ...
# 8248     ZIMBABWE              Tourism Industries
# 8249     ZIMBABWE              Tourism Industries
# 8250     ZIMBABWE              Tourism Industries
# 8251     ZIMBABWE              Tourism Industries
# 8252     ZIMBABWE              Tourism Industries
#
#                                                Category  \
# 0                                         Accommodation
# 1                                         Accommodation
# 2                                         Accommodation
# 3                                         Accommodation
# 4                                                 Trips
# ...

# %%
df = df.T

# %%
df
# Out:
#                                           0     \
# Country                            AFGHANISTAN
# Report Type     Domestic Tourism-Accommodation
# Category                         Accommodation
# Subcategory  Hotels and similar establishments
# Metric                                  Guests
# 1995                                       NaN
# 1996                                       NaN
# 1997                                       NaN
# 1998                                       NaN
# 1999                                       NaN
# 2000                                       NaN
# 2001                                       NaN
# 2002                                       NaN
# 2003                                       NaN
# 2004                                       NaN
# 2005                                       NaN
# 2006                                       NaN
# 2007                                       NaN
# 2008                                       NaN
# ...

# %%
print(df.head())
print(df.info())
print(df.describe(include='all'))
# Out:
#                                           0     \
# Country                            AFGHANISTAN
# Report Type     Domestic Tourism-Accommodation
# Category                         Accommodation
# Subcategory  Hotels and similar establishments
# Metric                                  Guests
#
#                                           1     \
# Country                            AFGHANISTAN
# Report Type     Domestic Tourism-Accommodation
# Category                         Accommodation
# Subcategory  Hotels and similar establishments
# Metric                              Overnights
#
#                                        2                               3     \
# Country                         AFGHANISTAN                     AFGHANISTAN
# Report Type  Domestic Tourism-Accommodation  Domestic Tourism-Accommodation
# Category                      Accommodation                   Accommodation
# Subcategory                           Total                           Total
# ...

# %%
df_melted = df.melt(id_vars=['Afganistan'], var_name='Country', value_name='Value')
print("\nMelted DataFrame:")
print(df_melted.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_melted = df.melt(id_vars=['Afganistan'], var_name='Country', value_name='Value')
#       2 print("\nMelted DataFrame:")
#       3 print(df_melted.head())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:9915, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9905 @Appender(_shared_docs["melt"] % {"caller": "df.melt(", "other": "melt"})
#    9906 def melt(
#    9907     self,
#    (...)
#    9913     ignore_index: bool = True,
#    9914 ) -> DataFrame:
# -> 9915     return melt(
#    9916         self,
#    9917         id_vars=id_vars,
#    9918         value_vars=value_vars,
#    9919         var_name=var_name,
#    9920         value_name=value_name,
#    9921         col_level=col_level,
# ...
